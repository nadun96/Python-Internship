# %%
import pandas as pd 
import numpy as np

# %%
nse_in_df = pd.read_csv('nse_indexes.csv')

# %%
nse_in_df.shape
# Out:
# (87536, 8)

# %%
# indexes_df = pd.read_csv('indexes_df.csv')

# %%
# stocks_df = pd.read_csv('stocks_df.csv')

# %%
nse_in_df.head()
# Out:
#          Date     Index     Open     High     Low   Close  Volume Currency
# 0  1995-11-06  NIFTY 50  1001.53  1001.53  988.92  988.92       0      INR
# 1  1995-11-07  NIFTY 50   987.17   987.17  977.05  978.22       0      INR
# 2  1995-11-08  NIFTY 50   976.28   976.28  962.98  964.01       0      INR
# 3  1995-11-09  NIFTY 50   960.32   960.32  952.13  953.07       0      INR
# 4  1995-11-10  NIFTY 50   951.93   951.93  946.00  948.82       0      INR

# %%
nse_in_df.tail()
# Out:
#              Date              Index     Open     High      Low    Close  \
# 87531  2022-01-24  NIFTY GS COMPSITE  2345.57  2345.57  2342.80  2342.95
# 87532  2022-01-25  NIFTY GS COMPSITE  2343.99  2346.21  2343.26  2343.60
# 87533  2022-01-27  NIFTY GS COMPSITE  2344.42  2344.42  2334.43  2334.50
# 87534  2022-01-28  NIFTY GS COMPSITE  2334.18  2335.28  2332.73  2333.30
# 87535  2022-01-31  NIFTY GS COMPSITE  2335.99  2337.80  2335.99  2337.64
#
#        Volume Currency
# 87531       0      INR
# 87532       0      INR
# 87533       0      INR
# 87534       0      INR
# 87535       0      INR

# %%
nse_in_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 87536 entries, 0 to 87535
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Date      87536 non-null  object
#  1   Index     87536 non-null  object
#  2   Open      87536 non-null  float64
#  3   High      87536 non-null  float64
#  4   Low       87536 non-null  float64
#  5   Close     87536 non-null  float64
#  6   Volume    87536 non-null  int64
#  7   Currency  87536 non-null  object
# dtypes: float64(4), int64(1), object(3)
# memory usage: 5.3+ MB

# %%
it_index = nse_in_df['Index'].unique()
it_index
# Out:
# array(['NIFTY 50', 'NIFTY NEXT 50', 'NIFTY BANK', 'INDIA VIX',
#        'NIFTY 100', 'NIFTY 500', 'NIFTY MIDCAP 100', 'NIFTY MIDCAP 50',
#        'NIFTY REALTY', 'NIFTY ENERGY', 'NIFTY FMCG', 'NIFTY MNC',
#        'NIFTY PHARMA', 'NIFTY PSE', 'NIFTY PSU BANK', 'NIFTY IT',
#        'NIFTY 200', 'NIFTY AUTO', 'NIFTY MEDIA', 'NIFTY METAL',
#        'NIFTY COMMODITIES', 'NIFTY CPSE', 'NIFTY ALPHA 50',
#        'NIFTY GS 8 13YR', 'NIFTY GS 10YR', 'NIFTY GS 4 8YR',
#        'NIFTY GS 11 15YR', 'NIFTY GS 15YRPLUS', 'NIFTY GS COMPSITE'],
#       dtype=object)

# %%
it_index_df = nse_in_df[nse_in_df['Index'] == 'NIFTY IT']
it_index_df
# Out:
#              Date     Index      Open      High       Low     Close    Volume  \
# 55221  2003-08-26  NIFTY IT   1352.77   1410.56   1352.77   1399.73         0
# 55222  2003-08-27  NIFTY IT   1415.69   1459.39   1415.69   1452.73         0
# 55223  2003-08-28  NIFTY IT   1462.39   1515.17   1462.39   1504.92         0
# 55224  2003-08-29  NIFTY IT   1507.12   1554.65   1493.26   1505.63         0
# 55225  2003-09-01  NIFTY IT   1505.79   1536.01   1505.08   1528.39         0
# ...           ...       ...       ...       ...       ...       ...       ...
# 59792  2022-01-24  NIFTY IT  35934.20  35969.85  34563.20  34821.60  36412976
# 59793  2022-01-25  NIFTY IT  34490.35  35065.80  33956.55  34707.45  41906056
# 59794  2022-01-27  NIFTY IT  34338.10  34362.85  33251.70  33475.05  49317844
# 59795  2022-01-28  NIFTY IT  33608.45  34473.50  33608.45  33851.95  48308300
# 59796  2022-01-31  NIFTY IT  34503.10  34925.65  34446.65  34742.00     15064
#
#       Currency
# 55221      INR
# ...

# %%
it_index_df['Date'].unique()
# Out:
# array(['2003-08-26', '2003-08-27', '2003-08-28', ..., '2022-01-27',
#        '2022-01-28', '2022-01-31'], dtype=object)

# %%
# Check for duplicates in the 'Date' column
duplicate_dates = it_index_df['Date'].duplicated().sum()

# %%
duplicate_dates
# Out:
# 0

# %%
import pandas as pd
from datetime import datetime

# Sample data
# data = {'Date': ['2003-08-26', '2003-08-27', '2003-08-28']}
# it_index_df = pd.DataFrame(data)

# Convert the 'Date' column to datetime by splitting and reconstructing
it_index_df['Date'] = it_index_df['Date'].apply(lambda x: datetime(*map(int, x.split('-'))))

# Verify the changes
print(it_index_df)
# Out:
#             Date     Index      Open      High       Low     Close    Volume  \
# 55221 2003-08-26  NIFTY IT   1352.77   1410.56   1352.77   1399.73         0
# 55222 2003-08-27  NIFTY IT   1415.69   1459.39   1415.69   1452.73         0
# 55223 2003-08-28  NIFTY IT   1462.39   1515.17   1462.39   1504.92         0
# 55224 2003-08-29  NIFTY IT   1507.12   1554.65   1493.26   1505.63         0
# 55225 2003-09-01  NIFTY IT   1505.79   1536.01   1505.08   1528.39         0
# ...          ...       ...       ...       ...       ...       ...       ...
# 59792 2022-01-24  NIFTY IT  35934.20  35969.85  34563.20  34821.60  36412976
# 59793 2022-01-25  NIFTY IT  34490.35  35065.80  33956.55  34707.45  41906056
# 59794 2022-01-27  NIFTY IT  34338.10  34362.85  33251.70  33475.05  49317844
# 59795 2022-01-28  NIFTY IT  33608.45  34473.50  33608.45  33851.95  48308300
# 59796 2022-01-31  NIFTY IT  34503.10  34925.65  34446.65  34742.00     15064
#
#       Currency
# 55221      INR
# ...

# %%
print(it_index_df.dtypes)
# Out:
# Date        datetime64[ns]
# Index               object
# Open               float64
# High               float64
# Low                float64
# Close              float64
# Volume               int64
# Currency            object
# dtype: object

# %%
it_index_df.shape
# Out:
# (4576, 8)

# %%
# it_index_df.set_index('Date', inplace=True)
# Set 'Date' as the index
it_index_df.set_index('Date', inplace=True)

# Verify the changes
print(it_index_df)
print(it_index_df.index)
# Out:
#                Index      Open      High       Low     Close    Volume  \
# Date
# 2003-08-26  NIFTY IT   1352.77   1410.56   1352.77   1399.73         0
# 2003-08-27  NIFTY IT   1415.69   1459.39   1415.69   1452.73         0
# 2003-08-28  NIFTY IT   1462.39   1515.17   1462.39   1504.92         0
# 2003-08-29  NIFTY IT   1507.12   1554.65   1493.26   1505.63         0
# 2003-09-01  NIFTY IT   1505.79   1536.01   1505.08   1528.39         0
# ...              ...       ...       ...       ...       ...       ...
# 2022-01-24  NIFTY IT  35934.20  35969.85  34563.20  34821.60  36412976
# 2022-01-25  NIFTY IT  34490.35  35065.80  33956.55  34707.45  41906056
# 2022-01-27  NIFTY IT  34338.10  34362.85  33251.70  33475.05  49317844
# 2022-01-28  NIFTY IT  33608.45  34473.50  33608.45  33851.95  48308300
# 2022-01-31  NIFTY IT  34503.10  34925.65  34446.65  34742.00     15064
#
#            Currency
# Date
# 2003-08-26      INR
# 2003-08-27      INR
# 2003-08-28      INR
# ...

# %%
# it_index_df.loc[:, 'Date'] = pd.to_datetime(it_index_df['Date'])
# it_index_df = it_index_df.copy()
# it_index_df['Date'] = pd.to_datetime(it_index_df['Date'])
# it_index_df.set_index('Date', inplace=True)

# Convert 'Date' column to datetime
# it_index_df['Date'] = pd.to_datetime(it_index_df['Date'])

# %%
# it_index_df.columns = it_index_df.columns.str.strip()

# %%
print(it_index_df.columns)
# Out:
# Index(['Index', 'Open', 'High', 'Low', 'Close', 'Volume', 'Currency'], dtype='object')

# %%
it_index_df.info
# Out:
# <bound method DataFrame.info of                Index      Open      High       Low     Close    Volume  \
# Date
# 2003-08-26  NIFTY IT   1352.77   1410.56   1352.77   1399.73         0
# 2003-08-27  NIFTY IT   1415.69   1459.39   1415.69   1452.73         0
# 2003-08-28  NIFTY IT   1462.39   1515.17   1462.39   1504.92         0
# 2003-08-29  NIFTY IT   1507.12   1554.65   1493.26   1505.63         0
# 2003-09-01  NIFTY IT   1505.79   1536.01   1505.08   1528.39         0
# ...              ...       ...       ...       ...       ...       ...
# 2022-01-24  NIFTY IT  35934.20  35969.85  34563.20  34821.60  36412976
# 2022-01-25  NIFTY IT  34490.35  35065.80  33956.55  34707.45  41906056
# 2022-01-27  NIFTY IT  34338.10  34362.85  33251.70  33475.05  49317844
# 2022-01-28  NIFTY IT  33608.45  34473.50  33608.45  33851.95  48308300
# 2022-01-31  NIFTY IT  34503.10  34925.65  34446.65  34742.00     15064
#
#            Currency
# Date
# 2003-08-26      INR
# 2003-08-27      INR
# ...

# %%
it_index_df.describe()
# Out:
#                Open          High           Low         Close        Volume
# count   4576.000000   4576.000000   4576.000000   4576.000000  4.576000e+03
# mean    9330.164921   9408.330896   9247.689731   9326.950328  4.417675e+07
# std     7078.049135   7132.138337   7017.503641   7073.294252  9.847899e+08
# min     1352.770000   1410.560000   1352.770000   1399.730000  0.000000e+00
# 25%     4442.250000   4480.350000   4393.962500   4431.937500  1.226350e+04
# 50%     6719.950000   6770.725000   6672.150000   6718.525000  1.044900e+07
# 75%    11535.312500  11603.962500  11445.075000  11536.275000  1.861225e+07
# max    39261.550000  39446.700000  38828.600000  39370.700000  4.229728e+10

# %%
print(it_index_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 4576 entries, 2003-08-26 to 2022-01-31
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Index     4576 non-null   object
#  1   Open      4576 non-null   float64
#  2   High      4576 non-null   float64
#  3   Low       4576 non-null   float64
#  4   Close     4576 non-null   float64
#  5   Volume    4576 non-null   int64
#  6   Currency  4576 non-null   object
# dtypes: float64(4), int64(1), object(2)
# memory usage: 286.0+ KB
# None

# %%
# it_index_df['Date'] = pd.to_datetime(it_index_df['Date'])

# %%
# it_index_df = it_index_df.set_index('Date')

# %%
it_index_df.index
# Out:
# DatetimeIndex(['2003-08-26', '2003-08-27', '2003-08-28', '2003-08-29',
#                '2003-09-01', '2003-09-02', '2003-09-03', '2003-09-04',
#                '2003-09-05', '2003-09-09',
#                ...
#                '2022-01-17', '2022-01-18', '2022-01-19', '2022-01-20',
#                '2022-01-21', '2022-01-24', '2022-01-25', '2022-01-27',
#                '2022-01-28', '2022-01-31'],
#               dtype='datetime64[ns]', name='Date', length=4576, freq=None)

# %%
from matplotlib import pyplot as plt

plt.figure(figsize=(10,5))
plt.plot(it_index_df.index,it_index_df['Close'])
plt.title('NIFTY IT Index')
plt.xlabel('Date')
plt.ylabel('Close')
plt.show()

# %%
from sklearn.model_selection import train_test_split

# Assuming 'it_index_df' is your DataFrame
train_df, test_df = train_test_split(it_index_df, test_size=0.1, random_state=42)

# Verify the split
print(f"Training set size: {len(train_df)}")
print(f"Testing set size: {len(test_df)}")
# Out:
# Training set size: 4118
# Testing set size: 458

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from tensorflow.keras.optimizers import Adam

# Sample data (assuming 'it_index_df' already has a 'Date' datetime index and a 'Close' column)
# Filter out Sunday (6) and Friday (4)
it_index_df = it_index_df[(it_index_df.index.dayofweek != 6) & (it_index_df.index.dayofweek != 4)]

# Scale the 'Close' prices
scaler = MinMaxScaler(feature_range=(0, 1))
it_index_df['Close'] = scaler.fit_transform(it_index_df[['Close']])

# Create sequences for LSTM
sequence_length = 60  # Number of previous time steps to consider
X, y = [], []
for i in range(sequence_length, len(it_index_df)):
    X.append(it_index_df['Close'].values[i-sequence_length:i])
    y.append(it_index_df['Close'].values[i])

X, y = np.array(X), np.array(y)

# Split into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=42)

# Reshape data to [samples, time steps, features]
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))

# Build the LSTM model
model = Sequential([
    LSTM(50, return_sequences=True, input_shape=(X_train.shape[1], 1)),
    LSTM(50, return_sequences=False),
    Dense(25),
    Dense(1)
])

# Compile the model
model.compile(optimizer=Adam(learning_rate=0.001), loss='mean_squared_error')

# Train the model
model.fit(X_train, y_train, batch_size=32, epochs=10, validation_data=(X_test, y_test))

# Evaluate the model on the test set
test_loss = model.evaluate(X_test, y_test)
print(f"Test Loss: {test_loss}")
# Out:
# C:\Users\udaraka\AppData\Local\Temp\ipykernel_13412\1183680022.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   it_index_df['Close'] = scaler.fit_transform(it_index_df[['Close']])
# C:\Users\udaraka\AppData\Roaming\Python\Python311\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/10
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 17s 94ms/step - loss: 0.0079 - val_loss: 1.4262e-04
# Epoch 2/10
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 8s 82ms/step - loss: 1.3152e-04 - val_loss: 1.5733e-04
# Epoch 3/10
# ...

# %%
import matplotlib.pyplot as plt

# Make predictions
train_predictions = model.predict(X_train)
test_predictions = model.predict(X_test)

# Inverse transform to get actual values
train_predictions = scaler.inverse_transform(train_predictions)
test_predictions = scaler.inverse_transform(test_predictions)
y_train_actual = scaler.inverse_transform(y_train.reshape(-1, 1))
y_test_actual = scaler.inverse_transform(y_test.reshape(-1, 1))

# Create a plot to view the predictions and actual values
plt.figure(figsize=(14, 7))

# Plot training data
plt.plot(np.arange(sequence_length, len(y_train_actual) + sequence_length), y_train_actual, label="Train Actual")
plt.plot(np.arange(sequence_length, len(train_predictions) + sequence_length), train_predictions, label="Train Prediction")

# Plot testing data
plt.plot(np.arange(len(y_train_actual) + 2 * sequence_length, len(y_train_actual) + len(y_test_actual) + 2 * sequence_length), y_test_actual, label="Test Actual")
plt.plot(np.arange(len(y_train_actual) + 2 * sequence_length, len(y_train_actual) + len(test_predictions) + 2 * sequence_length), test_predictions, label="Test Prediction")

# Add titles and labels
plt.title('LSTM Model Predictions vs Actual Values')
plt.xlabel('Days')
plt.ylabel('Close Price')
plt.legend()
plt.show()
# Out:
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 4s 33ms/step
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step

# %%
import matplotlib.pyplot as plt

# Make predictions
train_predictions = model.predict(X_train)
test_predictions = model.predict(X_test)

# Inverse transform to get actual values
train_predictions = scaler.inverse_transform(train_predictions)
test_predictions = scaler.inverse_transform(test_predictions)
y_train_actual = scaler.inverse_transform(y_train.reshape(-1, 1))
y_test_actual = scaler.inverse_transform(y_test.reshape(-1, 1))

# Create a plot to view the predictions and actual values
plt.figure(figsize=(14, 7))

# Plot training data
plt.plot(np.arange(sequence_length, len(y_train_actual) + sequence_length), y_train_actual, label="Train Actual")
plt.plot(np.arange(sequence_length, len(train_predictions) + sequence_length), train_predictions, label="Train Prediction")

# Plot testing data
plt.plot(np.arange(len(y_train_actual) + 2 * sequence_length, len(y_train_actual) + len(y_test_actual) + 2 * sequence_length), y_test_actual, label="Test Actual")
plt.plot(np.arange(len(y_train_actual) + 2 * sequence_length, len(y_train_actual) + len(test_predictions) + 2 * sequence_length), test_predictions, label="Test Prediction")

# Add titles and labels
plt.title('LSTM Model Predictions vs Actual Values')
plt.xlabel('Days')
plt.ylabel('Close Price')
plt.legend()
plt.show()
# Out:
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step

# %%
import matplotlib.pyplot as plt

# Make predictions
train_predictions = model.predict(X_train)
test_predictions = model.predict(X_test)

# Inverse transform to get actual values
train_predictions = scaler.inverse_transform(train_predictions)
test_predictions = scaler.inverse_transform(test_predictions)
y_train_actual = scaler.inverse_transform(y_train.reshape(-1, 1))
y_test_actual = scaler.inverse_transform(y_test.reshape(-1, 1))

# Create an array of dates for the x-axis
train_dates = it_index_df.index[sequence_length:len(y_train_actual) + sequence_length]
test_dates = it_index_df.index[len(y_train_actual) + 2 * sequence_length:len(y_train_actual) + len(y_test_actual) + 2 * sequence_length]

# Create a plot to view the predictions and actual values
plt.figure(figsize=(14, 7))

# Plot training data
plt.plot(train_dates, y_train_actual, label="Train Actual", color='blue')
plt.plot(train_dates, train_predictions, label="Train Prediction", color='lightblue')

# Plot testing data
plt.plot(test_dates, y_test_actual, label="Test Actual", color='orange')
plt.plot(test_dates, test_predictions, label="Test Prediction", color='lightcoral')

# Add titles and labels
plt.title('LSTM Model Predictions vs Actual Values')
plt.xlabel('Date')
plt.ylabel('Close Price')

# Set x-ticks to show actual dates
plt.xticks(ticks=np.arange(0, len(train_dates) + len(test_dates), 5), 
           labels=[date.strftime('%Y-%m-%d') for date in np.concatenate((train_dates[:len(train_dates)], test_dates[:len(test_dates)]))][::5], 
           rotation=45)  # Adjust the tick frequency as needed

plt.legend()
plt.tight_layout()  # Adjust layout to make room for rotated x-ticks
plt.show()
# Out:
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[137], line 25
#      22 plt.plot(train_dates, train_predictions, label="Train Prediction", color='lightblue')
#      24 # Plot testing data
# ---> 25 plt.plot(test_dates, y_test_actual, label="Test Actual", color='orange')
#      26 plt.plot(test_dates, test_predictions, label="Test Prediction", color='lightcoral')
#      28 # Add titles and labels
#
# File d:\ProgramData\anaconda3\Lib\site-packages\matplotlib\pyplot.py:3578, in plot(scalex, scaley, data, *args, **kwargs)
#    3570 @_copy_docstring_and_deprecators(Axes.plot)
#    3571 def plot(
#    3572     *args: float | ArrayLike | str,
#    (...)
#    3576     **kwargs,
#    3577 ) -> list[Line2D]:
# -> 3578     return gca().plot(
#    3579         *args,
# ...

# %%
import matplotlib.pyplot as plt

# Make predictions
train_predictions = model.predict(X_train)
test_predictions = model.predict(X_test)

# Inverse transform to get actual values
train_predictions = scaler.inverse_transform(train_predictions)
test_predictions = scaler.inverse_transform(test_predictions)
y_train_actual = scaler.inverse_transform(y_train.reshape(-1, 1))
y_test_actual = scaler.inverse_transform(y_test.reshape(-1, 1))

# Create an array of dates for the x-axis
train_dates = it_index_df.index[sequence_length:len(y_train_actual) + sequence_length]
test_dates = it_index_df.index[len(y_train_actual) + 2 * sequence_length:len(y_train_actual) + len(y_test_actual) + 2 * sequence_length]

# Create a plot to view the predictions and actual values
plt.figure(figsize=(14, 7))

# Plot training data
plt.plot(train_dates, y_train_actual, label="Train Actual", color='blue')
plt.plot(train_dates, train_predictions, label="Train Prediction", color='lightblue')

# Plot testing data
plt.plot(test_dates, y_test_actual.flatten(), label="Test Actual", color='orange')  # Flatten the array
plt.plot(test_dates, test_predictions, label="Test Prediction", color='lightcoral')

# Add titles and labels
plt.title('LSTM Model Predictions vs Actual Values')
plt.xlabel('Date')
plt.ylabel('Close Price')

# Set x-ticks to show actual dates
plt.xticks(ticks=np.arange(0, len(train_dates) + len(test_dates), 5), 
           labels=[date.strftime('%Y-%m-%d') for date in np.concatenate((train_dates[:len(train_dates)], test_dates[:len(test_dates)]))][::5], 
           rotation=45)  # Adjust the tick frequency as needed

# Add legend to identify lines
plt.legend()

# Optionally, add line labels (not annotations)
# You can place the labels at the end of each line
plt.text(train_dates[-1], y_train_actual[-1], 'Train Actual', color='blue', fontsize=10, verticalalignment='bottom')
plt.text(train_dates[-1], train_predictions[-1], 'Train Prediction', color='lightblue', fontsize=10, verticalalignment='bottom')
plt.text(test_dates[-1], y_test_actual.flatten()[-1], 'Test Actual', color='orange', fontsize=10, verticalalignment='bottom')
plt.text(test_dates[-1], test_predictions[-1], 'Test Prediction', color='lightcoral', fontsize=10, verticalalignment='bottom')

plt.tight_layout()  # Adjust layout to make room for rotated x-ti
# Out:
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[139], line 25
#      22 plt.plot(train_dates, train_predictions, label="Train Prediction", color='lightblue')
#      24 # Plot testing data
# ---> 25 plt.plot(test_dates, y_test_actual.flatten(), label="Test Actual", color='orange')  # Flatten the array
#      26 plt.plot(test_dates, test_predictions, label="Test Prediction", color='lightcoral')
#      28 # Add titles and labels
#
# File d:\ProgramData\anaconda3\Lib\site-packages\matplotlib\pyplot.py:3578, in plot(scalex, scaley, data, *args, **kwargs)
#    3570 @_copy_docstring_and_deprecators(Axes.plot)
#    3571 def plot(
#    3572     *args: float | ArrayLike | str,
#    (...)
#    3576     **kwargs,
#    3577 ) -> list[Line2D]:
# -> 3578     return gca().plot(
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np

# Make predictions
train_predictions = model.predict(X_train)
test_predictions = model.predict(X_test)

# Inverse transform to get actual values
train_predictions = scaler.inverse_transform(train_predictions)
test_predictions = scaler.inverse_transform(test_predictions)
y_train_actual = scaler.inverse_transform(y_train.reshape(-1, 1))
y_test_actual = scaler.inverse_transform(y_test.reshape(-1, 1))

# Create an array of dates for the x-axis
train_dates = it_index_df.index[sequence_length:len(y_train_actual) + sequence_length]
test_dates_start_index = len(y_train_actual) + 2 * sequence_length
test_dates = it_index_df.index[test_dates_start_index:test_dates_start_index + len(y_test_actual)]

# Debugging: Check shapes of dates and actual values
print("Train Dates Shape:", train_dates.shape)
print("Train Actual Shape:", y_train_actual.shape)
print("Test Dates Shape:", test_dates.shape)
print("Test Actual Shape:", y_test_actual.shape)

# Create a plot to view the predictions and actual values
plt.figure(figsize=(14, 7))

# Plot training data
plt.plot(train_dates, y_train_actual, label="Train Actual", color='blue')
plt.plot(train_dates, train_predictions, label="Train Prediction", color='lightblue')

# Plot testing data
plt.plot(test_dates, y_test_actual.flatten(), label="Test Actual", color='orange')  # Flatten the array
plt.plot(test_dates, test_predictions, label="Test Prediction", color='lightcoral')

# Add titles and labels
plt.title('LSTM Model Predictions vs Actual Values')
plt.xlabel('Date')
plt.ylabel('Close Price')

# Set x-ticks to show actual dates
plt.xticks(ticks=np.arange(0, len(train_dates) + len(test_dates), 5), 
           labels=[date.strftime('%Y-%m-%d') for date in np.concatenate((train_dates[:len(train_dates)], test_dates[:len(test_dates)]))][::5], 
           rotation=45)  # Adjust the tick frequency as needed

# Add legend to identify lines
plt.legend()

# Optionally, add line labels (not annotations)
# You can place the labels at the end of each line
plt.text(train_dates[-1], y_train_actual[-1], 'Train Actual', color='blue', fontsize=10, verticalalignment='bottom')
plt.text(train_dates[-1], train_predictions[-1], 'Train Prediction', color='lightblue', fontsize=10, verticalalignment='bottom')
plt.text(test_dates[-1], y_test_actual.flatten()[-1], 'Test Actual', color='orange', fontsize=10, verticalalignment='bottom')
plt.text(test_dates[-1], test_predictions[-1], 'Test Prediction', color='lightcoral', fontsize=10, verticalalignment='bottom')

plt.tight_layout()  # Adjust layout to make room for rotated x-ticks
plt.show()
# Out:
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 4s 36ms/step
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# Train Dates Shape: (3251,)
# Train Actual Shape: (3251, 1)
# Test Dates Shape: (302,)
# Test Actual Shape: (362, 1)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[140], line 33
#      30 plt.plot(train_dates, train_predictions, label="Train Prediction", color='lightblue')
#      32 # Plot testing data
# ---> 33 plt.plot(test_dates, y_test_actual.flatten(), label="Test Actual", color='orange')  # Flatten the array
#      34 plt.plot(test_dates, test_predictions, label="Test Prediction", color='lightcoral')
#      36 # Add titles and labels
#
# File d:\ProgramData\anaconda3\Lib\site-packages\matplotlib\pyplot.py:3578, in plot(scalex, scaley, data, *args, **kwargs)
#    3570 @_copy_docstring_and_deprecators(Axes.plot)
#    3571 def plot(
#    3572     *args: float | ArrayLike | str,
# ...
